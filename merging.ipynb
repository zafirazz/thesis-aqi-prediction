# %%
import os
import pandas as pd

def merge_csv_files(input_folder: str, output_file: str):
    csv_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]
    
    if not csv_files:
        print("No CSV files found in the folder.")
        return
    df_list = [pd.read_csv(os.path.join(input_folder, file), sep=";", decimal=",") for file in csv_files]
    merged_df = pd.concat(df_list, ignore_index=True)
    
    merged_df.to_csv(output_file, index=False, sep=";", decimal=",")
    print(f"Merged {len(csv_files)} files into {output_file}")

if __name__ == "__main__":
    input_folder = "/Users/zafiraibraeva/Code/uni coding/thesis/dataset/debrecen hajnal hour "  
    output_file = "/dataset/full_data/hourly/AQI_hajnal_hourly.csv"
    merge_csv_files(input_folder, output_file)
# Out:
# Merged 11 files into /Users/zafiraibraeva/Code/uni coding/thesis/dataset/full_data/AQI_hajnal_hourly.csv

# %% [markdown]
# ## Now that we got two csv files from each station in Debrecen, we will process it and merge it into one.

# %%
def merge_csv_files(input_folder: str, output_file: str):
    csv_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]
    
    if not csv_files:
        print("No CSV files found in the folder.")
        return
    
    dataframes = {}
    for i, file in enumerate(csv_files):
        df = pd.read_csv(os.path.join(input_folder, file), sep=";", decimal=",")
        df.rename(columns={col: f"Station{i+1}_{col}" for col in df.columns if col != "Date"}, inplace=True)
        dataframes[f"Station{i+1}"] = df
    
    merged_df = None
    for df in dataframes.values():
        if merged_df is None:
            merged_df = df
        else:
            merged_df = pd.merge(merged_df, df, on="Date", how="outer")
    
    merged_df.to_csv(output_file, index=False, sep=";", decimal=",")
    print(f"Merged {len(csv_files)} files into {output_file}")

if __name__ == "__main__":
    input_folder = "/Users/zafiraibraeva/Code/uni coding/thesis/dataset/full_data/hourly" 
    output_file = "/Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/AQI data/AQI_hourly.csv"
    merge_csv_files(input_folder, output_file)
# Out:
# Merged 2 files into /Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/AQI data/AQI_hourly.csv

# %% [markdown]
# ## Now we need to preprocess and merge wind data with AQI

# %%
import pandas as pd

file1 = '/Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/wind/wind.csv'
file2 = '/Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/wind/Debrecen 2023-05-01 to 2023-12-31.csv'

output_file = '/Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/final_data/wind.csv'

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

merged_df = pd.concat([df1, df2], ignore_index=True)
merged_df.to_csv(output_file, index=False)

print(f"Merged CSV saved to {output_file}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 8
#       4 file2 = '/Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/wind/Debrecen 2023-05-01 to 2023-12-31.csv'
#       6 output_file = '/Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/final_data/wind.csv'
# ----> 8 df1 = pd.read_csv(file1)
#       9 df2 = pd.read_csv(file2)
#      11 merged_df = pd.concat([df1, df2], ignore_index=True)
#
# ...

# %%
merged_df = pd.read_csv("/Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/final_data/wind.csv")
merged_df.drop('name', axis=1, inplace=True)
m
# Out:
#                                                                          datetime  \
# Debrecen                                           2023-05-01 22.5 8.6       22.5
# Debrecen,2023-05-02,24,9.3,17.6,24,8.5,17.6,6.6... NaN        NaN  NaN        NaN
# Debrecen,2023-05-03,23.5,11.6,17.1,23.5,11.6,17... NaN        NaN  NaN        NaN
# Debrecen,2023-05-04,21.5,11.1,16,21.5,11.1,16,7... NaN        NaN  NaN        NaN
# Debrecen,2023-05-05,22.3,8.1,15.6,22.3,8.1,15.6... NaN        NaN  NaN        NaN
# ...                                                                           ...
# Debrecen,2015-12-27,3.4,1,2.3,3.4,-0.6,1.3,2.2,... NaN        NaN  NaN        NaN
# Debrecen,2015-12-28,2.4,0.7,1.2,2.4,-2.2,-0.5,1... NaN        NaN  NaN        NaN
# Debrecen,2015-12-29,6.8,-0.6,2.7,3.6,-6.2,-1.3,... NaN        NaN  NaN        NaN
# Debrecen,2015-12-30,1.4,-5.3,-1.7,-4.2,-10.8,-7... NaN        NaN  NaN        NaN
# ...

# %%
merged_df.

# %%
merged_df.set_index('datetime', inplace=True)

# %%
merged_df.isnull().sum()
# Out:
# tempmax             4013
# tempmin             4013
# temp                4013
# feelslikemax        4013
# feelslikemin        4013
# feelslike           4013
# dew                 4013
# humidity            4013
# precip              4013
# precipprob          4013
# precipcover         4013
# preciptype          4018
# snow                4013
# snowdepth           4013
# windgust            4013
# windspeed           4013
# winddir             4013
# sealevelpressure    4013
# cloudcover          4013
# visibility          4013
# solarradiation      4013
# solarenergy         4013
# uvindex             4013
# severerisk          4018
# sunrise             4013
# sunset              4013
# moonphase           4013
# conditions          4013
# description         4013
# icon                4013
# stations            4013
# dtype: int64

# %%
# Out:
#           tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike  dew  \
# datetime
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
# ...           ...      ...   ...           ...           ...        ...  ...
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
# NaN           NaN      NaN   NaN           NaN           NaN        NaN  NaN
#
# ...

# %%
import os
import pandas as pd

def merge_csv_files(source_folder: str, destination_folder: str, output_filename: str = "wind.csv"):
    """
    Merges all CSV files in the source folder into a single CSV file and saves it in the destination folder.
    
    :param source_folder: Path to the folder containing the CSV files to merge.
    :param destination_folder: Path to the folder where the merged CSV file will be saved.
    :param output_filename: Name of the output merged CSV file (default: "wind.csv").
    """
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    
    csv_files = [f for f in os.listdir(source_folder) if f.endswith('.csv')]
    
    if not csv_files:
        print("No CSV files found in the source folder.")
        return
    
    dataframes = [pd.read_csv(os.path.join(source_folder, file)) for file in csv_files]
    merged_df = pd.concat(dataframes, ignore_index=True)
    
    output_path = os.path.join(destination_folder, output_filename)
    merged_df.to_csv(output_path, index=False)
    
    print(f"Merged {len(csv_files)} CSV files into {output_path}")

# Example usage
source_folder = "/Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/wind"
destination_folder = "/Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/final_data/wind.csv"
merge_csv_files(source_folder, destination_folder)
# Out:
# Merged 6 CSV files into /Users/zafiraibraeva/Code/uni coding/thesis/thesis_code/thesis/data/final_data/wind.csv/merged.csv
